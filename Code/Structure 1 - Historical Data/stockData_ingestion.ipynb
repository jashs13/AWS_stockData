# %%
# !pip install yfinance

# %% [markdown]
# SEND RAW DATA TO AWS S3 using python's boto3 module

# %%
pip install boto3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 46.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 9.3 MB/s eta 0:00:00
# ...

# %%
import boto3

# AWS credentials and S3 bucket details
aws_access_key_id = ''
aws_secret_access_key = ''
bucket_name = 'stockrawdatabucket'
file_key = 'combined_df_data.csv'  # Change this according to your desired S3 path and filename

# %% [markdown]
# Code to delete bucket - DONT RUN UNLESS YOU WANT TO DELETE

# %%
#s3 = boto3.client('s3', aws_access_key_id='AKIAV32AY3JDGLFUV5JB', aws_secret_access_key='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')
#s3.delete_object(Bucket=bucket_name, Key=file_key);

# %% [markdown]
# ### Upload CSV data to S3

# %%
# Upload CSV data to S3
s3_client = boto3.client('s3', aws_access_key_id='', aws_secret_access_key='')

try:
    s3_client.put_object(Body=csv_data, Bucket=bucket_name, Key=file_key)
    print("Upload Successful")
except NoCredentialsError:
    print("Credentials not available")
# Out:
# Upload Successful

# %%
tickers = ['META']
fb_df = yf.download(tickers, start='2001-01-31', end='2023-12-01', actions = True, group_by = "Ticker", auto_adjust = True)
csv_data_meta = fb_df.to_csv()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
fb_df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2012-05-18   42.049999   45.000000   38.000000   38.230000  573576400
# 2012-05-21   36.529999   36.660000   33.000000   34.029999  168192700
# 2012-05-22   32.610001   33.590000   30.940001   31.000000  101786600
# 2012-05-23   31.370001   32.500000   31.360001   32.000000   73600000
# 2012-05-24   32.950001   33.209999   31.770000   33.029999   50237200
# ...                ...         ...         ...         ...        ...
# 2023-11-24  340.130005  341.859985  336.769989  338.230011    5467500
# 2023-11-27  336.179993  339.899994  334.200012  334.700012   15684500
# 2023-11-28  333.399994  339.380005  333.399994  338.989990   12637200
# 2023-11-29  339.690002  339.899994  330.779999  332.200012   16024500
# 2023-11-30  331.890015  333.500000  322.399994  327.149994   23146400
#
#             Dividends  Stock Splits
# Date
# 2012-05-18        0.0           0.0
# 2012-05-21        0.0           0.0
# ...

# %%
tickers = ['TSLA']
tsla_df = yf.download(tickers, start='2001-01-31', end='2023-12-01', actions = True, group_by = "Ticker", auto_adjust = True)
csv_data_meta = tsla_df.to_csv()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tsla_df
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667  281494500
# 2010-06-30    1.719333    2.028000    1.553333    1.588667  257806500
# 2010-07-01    1.666667    1.728000    1.351333    1.464000  123282000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000   77097000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000  103003500
# ...                ...         ...         ...         ...        ...
# 2023-11-24  233.750000  238.750000  232.330002  235.449997   65125200
# 2023-11-27  236.889999  238.330002  232.100006  236.080002  112031800
# 2023-11-28  236.679993  247.000000  234.009995  246.720001  148549900
# 2023-11-29  249.210007  252.750000  242.759995  244.139999  135401300
# 2023-11-30  245.139999  245.220001  236.910004  240.080002  132353200
#
#             Dividends  Stock Splits
# Date
# 2010-06-29        0.0           0.0
# 2010-06-30        0.0           0.0
# ...

# %%
tickers = ['URTH']
urth_df = yf.download(tickers, start='2001-01-31', end='2023-12-01', actions = True, group_by = "Ticker", auto_adjust = True)
csv_data_meta = urth_df.to_csv()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf

tickers = ["AAPL","NFLX","GOOGL","MSFT","AMZN","NVDA","META","TSLA","URTH"]

# %%
# Download stock data for companies individually
apple_stock_df = yf.download(tickers[0], start='2004-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = apple_stock_df.to_csv()

# Apple stock dataframe
apple_stock_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume  \
# Date
# 2004-01-02    0.326205    0.329233    0.320604    0.322118  144642400
# 2004-01-05    0.324237    0.338920    0.324237    0.335590  395018400
# 2004-01-06    0.336801    0.339375    0.328628    0.334379  509348000
# 2004-01-07    0.334531    0.345581    0.331957    0.341948  586874400
# 2004-01-08    0.345732    0.359204    0.342856    0.353604  460303200
# ...                ...         ...         ...         ...        ...
# 2023-11-24  190.869995  190.899994  189.250000  189.970001   24048300
# 2023-11-27  189.919998  190.669998  188.899994  189.789993   40552600
# 2023-11-28  189.779999  191.080002  189.399994  190.399994   38415400
# 2023-11-29  190.899994  192.089996  188.970001  189.369995   43014200
# 2023-11-30  189.839996  190.320007  188.190002  189.949997   48794400
#
#             Dividends  Stock Splits
# Date
# ...

# %%
# Download stock data for companies individually
netflix_stock_df = yf.download(tickers[1], start='2004-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = netflix_stock_df.to_csv()

# Netflix stock dataframe
netflix_stock_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close    Volume  \
# Date
# 2004-01-02    4.107143    4.127857    3.842143    3.916429  50230600
# 2004-01-05    3.892857    4.061429    3.875000    3.992857  25207000
# 2004-01-06    3.946429    4.339286    3.937143    4.257857  52633000
# 2004-01-07    4.307143    4.470000    4.249286    4.445714  68432000
# 2004-01-08    4.539286    4.564286    4.291429    4.432857  37178400
# ...                ...         ...         ...         ...       ...
# 2023-11-24  477.109985  480.399994  475.200012  479.559998   1404700
# 2023-11-27  479.029999  482.000000  475.350006  479.170013   3625900
# 2023-11-28  478.109985  480.500000  475.950012  479.000000   2890200
# 2023-11-29  479.000000  480.989990  474.489990  477.190002   2855500
# 2023-11-30  475.309998  478.589996  470.420013  473.970001   4287300
#
#             Dividends  Stock Splits
# Date
# ...

# %%
# Download stock data for companies individually
goog_stock_df = yf.download(tickers[2], start='2004-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = goog_stock_df.to_csv()

# Google stock dataframe
goog_stock_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume  \
# Date
# 2004-08-19    2.502503    2.604104    2.401401    2.511011  893181924
# 2004-08-20    2.527778    2.729730    2.515015    2.710460  456686856
# 2004-08-23    2.771522    2.839840    2.728979    2.737738  365122512
# 2004-08-24    2.783784    2.792793    2.591842    2.624374  304946748
# 2004-08-25    2.626627    2.702703    2.599600    2.652653  183772044
# ...                ...         ...         ...         ...        ...
# 2023-11-24  138.029999  138.130005  135.990005  136.690002   12514300
# 2023-11-27  136.029999  138.419998  136.000000  136.410004   23436500
# 2023-11-28  136.080002  137.250000  135.419998  137.199997   18730000
# 2023-11-29  137.570007  138.289993  134.839996  134.990005   23967200
# 2023-11-30  135.050003  135.550003  131.279999  132.529999   38988300
#
#             Dividends  Stock Splits
# Date
# ...

# %%
# Download stock data for companies individually
msft_stock_df = yf.download(tickers[3], start='2004-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = msft_stock_df.to_csv()

# Microsoft stock dataframe
msft_stock_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close    Volume  \
# Date
# 2004-01-02   17.249812   17.368647   17.093451   17.168505  44487700
# 2004-01-05   17.343628   17.625080   17.337374   17.600061  67333700
# 2004-01-06   17.631333   17.687624   17.556279   17.662605  46950800
# 2004-01-07   17.618829   17.706391   17.518758   17.643847  54298200
# 2004-01-08   17.756422   17.812712   17.512498   17.612570  58810800
# ...                ...         ...         ...         ...       ...
# 2023-11-24  377.329987  377.970001  375.140015  377.429993  10176600
# 2023-11-27  376.779999  380.640015  376.200012  378.609985  22179200
# 2023-11-28  378.350006  383.000000  378.160004  382.700012  20453100
# 2023-11-29  383.760010  384.299988  377.440002  378.850006  28963400
# 2023-11-30  378.489990  380.089996  375.470001  378.910004  30554400
#
#             Dividends  Stock Splits
# Date
# ...

# %%
# Download stock data for companies individually
amzn_stock_df = yf.download(tickers[4], start='2004-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = amzn_stock_df.to_csv()

# Amazon stock dataframe
amzn_stock_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume  \
# Date
# 2004-01-02    2.638000    2.656500    2.571500    2.595000  132798000
# 2004-01-05    2.600000    2.680000    2.568500    2.663500  225682000
# 2004-01-06    2.655500    2.675000    2.637000    2.651500  119710000
# 2004-01-07    2.609000    2.633000    2.547000    2.595000  184854000
# 2004-01-08    2.604500    2.605000    2.501500    2.512000  206406000
# ...                ...         ...         ...         ...        ...
# 2023-11-24  146.699997  147.199997  145.320007  146.740005   22378400
# 2023-11-27  147.529999  149.259995  146.880005  147.729996   53762400
# 2023-11-28  146.979996  147.600006  145.529999  147.029999   42711700
# 2023-11-29  147.850006  148.539993  145.970001  146.320007   40610900
# 2023-11-30  144.759995  146.929993  144.330002  146.089996   65814000
#
#             Dividends  Stock Splits
# Date
# ...

# %%
# Download stock data for companies individually
nvda_stock_df = yf.download(tickers[5], start='2004-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = goog_stock_df.to_csv()

# Nividia stock dataframe
nvda_stock_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume  \
# Date
# 2004-01-02    1.801819    1.826281    1.764360    1.764360   43641600
# 2004-01-05    1.791116    1.833926    1.775063    1.821694   57529200
# 2004-01-06    1.816344    1.921074    1.807934    1.895847  109334400
# 2004-01-07    1.874442    1.921838    1.861447    1.912665   67303200
# 2004-01-08    1.936362    1.945536    1.901198    1.919545   43375200
# ...                ...         ...         ...         ...        ...
# 2023-11-24  484.657410  489.166993  477.408047  477.718018   29464500
# 2023-11-27  477.957969  485.257315  476.478088  482.377594   39566200
# 2023-11-28  482.317567  483.187516  474.688264  478.167938   40149100
# 2023-11-29  483.747471  487.577120  478.557924  481.357666   38200500
# 2023-11-30  480.197781  481.057721  464.179200  467.658905   52624700
#
#             Dividends  Stock Splits
# Date
# ...

# %%
# Download stock data for companies individually
meta_stock_df = yf.download(tickers[6], start='2012-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = meta_stock_df.to_csv()

# Meta stock dataframe
meta_stock_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume  \
# Date
# 2012-05-18   42.049999   45.000000   38.000000   38.230000  573576400
# 2012-05-21   36.529999   36.660000   33.000000   34.029999  168192700
# 2012-05-22   32.610001   33.590000   30.940001   31.000000  101786600
# 2012-05-23   31.370001   32.500000   31.360001   32.000000   73600000
# 2012-05-24   32.950001   33.209999   31.770000   33.029999   50237200
# ...                ...         ...         ...         ...        ...
# 2023-11-24  340.130005  341.859985  336.769989  338.230011    5467500
# 2023-11-27  336.179993  339.899994  334.200012  334.700012   15684500
# 2023-11-28  333.399994  339.380005  333.399994  338.989990   12637200
# 2023-11-29  339.690002  339.899994  330.779999  332.200012   16024500
# 2023-11-30  331.890015  333.500000  322.399994  327.149994   23146400
#
#             Dividends  Stock Splits
# Date
# ...

# %%
# Download stock data for companies individually
tsla_stock_df = yf.download(tickers[7], start='2010-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = tsla_stock_df.to_csv()

# Tesla stock dataframe
tsla_stock_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close     Volume  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667  281494500
# 2010-06-30    1.719333    2.028000    1.553333    1.588667  257806500
# 2010-07-01    1.666667    1.728000    1.351333    1.464000  123282000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000   77097000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000  103003500
# ...                ...         ...         ...         ...        ...
# 2023-11-24  233.750000  238.750000  232.330002  235.449997   65125200
# 2023-11-27  236.889999  238.330002  232.100006  236.080002  112031800
# 2023-11-28  236.679993  247.000000  234.009995  246.720001  148549900
# 2023-11-29  249.210007  252.750000  242.759995  244.139999  135401300
# 2023-11-30  245.139999  245.220001  236.910004  240.080002  132353200
#
#             Dividends  Stock Splits
# Date
# ...

# %%
# Download stock data for companies individually
urth_idx_df = yf.download(tickers[8], start='2012-01-01', end='2023-12-01', actions=True, group_by='Ticker', auto_adjust = True)

# Convert DataFrame to CSV
csv_data = urth_idx_df.to_csv()

# Urth index for comparison dataframe
urth_idx_df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close  Volume  Dividends  \
# Date
# 2012-01-12   40.000214   40.000214   40.000214   40.000214     100        0.0
# 2012-01-13   40.000214   40.000214   40.000214   40.000214       0        0.0
# 2012-01-17   40.000214   40.000214   40.000214   40.000214       0        0.0
# 2012-01-18   40.000214   40.000214   40.000214   40.000214       0        0.0
# 2012-01-19   41.177143   41.177143   41.177143   41.177143     300        0.0
# ...                ...         ...         ...         ...     ...        ...
# 2023-11-24  127.279999  127.559998  127.269997  127.519997  253200        0.0
# 2023-11-27  127.309998  127.500000  127.180000  127.309998  690000        0.0
# 2023-11-28  127.089996  127.750000  127.000000  127.410004  233000        0.0
# 2023-11-29  127.980003  128.199997  127.330002  127.430000  666400        0.0
# ...
